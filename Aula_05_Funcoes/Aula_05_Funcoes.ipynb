# %% [markdown]
# # Aula 05 — Funções
#
# **Curso:** Introdução ao Python no Google Colab
#
# ## Objetivos da aula
# - Criar funções com `def`.
# - Usar parâmetros.
# - Usar retorno.
# - Organizar melhor o código.

# %% [markdown]
# ## Parte teórica
# Funções são blocos de código reutilizáveis. Elas tornam o programa mais organizado, evitam repetição e facilitam manutenção.

# %% [markdown]
# ## Criando uma função

# %%
def saudacao():
    print('Olá! Seja bem-vindo ao curso de Python.')

saudacao()

# %% [markdown]
# ## Função com parâmetros

# %%
def somar(a, b):
    resultado = a + b
    print('Resultado:', resultado)

somar(10, 5)

# %% [markdown]
# ## Função com retorno

# %%
def calcular_media(n1, n2, n3):
    return (n1 + n2 + n3) / 3

media = calcular_media(7, 8, 9)
print('Média:', media)

# %% [markdown]
# ## Mini calculadora científica

# %%
def soma(a, b):
    return a + b

def subtracao(a, b):
    return a - b

def multiplicacao(a, b):
    return a * b

def divisao(a, b):
    return a / b

x = float(input('Digite x: '))
y = float(input('Digite y: '))

print('Soma:', soma(x, y))
print('Subtração:', subtracao(x, y))
print('Multiplicação:', multiplicacao(x, y))
print('Divisão:', divisao(x, y))

# %% [markdown]
# ## Exercícios propostos
# 1. Crie uma função que calcule área do círculo.
# 2. Crie uma função que receba uma idade e diga se é maior de idade.
# 3. Crie uma função que calcule média de uma lista de notas.

# %% [markdown]
# ## Mini projeto da aula
# Crie uma calculadora com funções para as quatro operações básicas.
